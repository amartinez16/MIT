# %% [markdown]
# # Actividad evaluable del módulo 6: Redes generativas antagónicas convolucionales profundas (DCGAN)
#
# En esta actividad, exploraremos la implementación de redes generativas antagónicas convolucionales profundas (DCGAN). Las GAN generaron un gran interés como aplicación de las redes neuronales profundas. Pytorch contiene código para implementar DCGAN, así como un tutorial. Para esta actividad, hemos adaptado el código disponible en el tutorial.
#
# Para completar esta actividad, deberá entrenar redes de discriminación y generación para crear nuevas flores a partir del conjunto de datos de flores Oxford102flowers, disponible en Pytorch. Como aún no hemos mostrado ejemplos del proceso de entrenamiento de una GAN, el cuaderno incluye el código básico necesario.
#
# Nota: entrenar estas GAN durante 100 ciclos requiere unos 15 minutos en un cuaderno de Colab si se utiliza una GPU.

# %%
import torch
import torch.nn as nn
import numpy as np
import torchvision.datasets
from torchvision.datasets import ImageFolder
import torchvision.utils as vutils
from torchvision import transforms
from torch.utils.data import Subset
from torch.utils.data import DataLoader
from torch.nn.modules.flatten import Flatten
import time, copy
import matplotlib.pyplot as plt
import sklearn.metrics as metrics

# Configuración del dispositivo (si es posible, entrenar el modelo en la GPU, el proceso será mucho más rápido)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataroot = "/content/drive/MyDrive/Dataset/data/celeba/img_align_celeba"

# %%
#dataroot = "data/celeba"
image_size = 64

# %%
# Estas transformaciones sucederán en todos los puntos de datos. En este ejemplo,
# queremos convertir cada punto de datos en un tensor y realizar una normalización

transform = transforms.Compose([
                               transforms.Resize(image_size),
                               transforms.CenterCrop(image_size),
                               transforms.ToTensor(),
                               transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                           ])

flowers_train = torchvision.datasets.Flowers102('', split = "train", transform =transform, download=True)
# Out:
# Downloading https://thor.robots.ox.ac.uk/datasets/flowers-102/102flowers.tgz to flowers-102/102flowers.tgz
# 100%|██████████| 344862509/344862509 [00:17<00:00, 20145804.14it/s]
# Extracting flowers-102/102flowers.tgz to flowers-102
# Downloading https://thor.robots.ox.ac.uk/datasets/flowers-102/imagelabels.mat to flowers-102/imagelabels.mat
# 100%|██████████| 502/502 [00:00<00:00, 567990.45it/s]
# Downloading https://thor.robots.ox.ac.uk/datasets/flowers-102/setid.mat to flowers-102/setid.mat
# 100%|██████████| 14989/14989 [00:00<00:00, 39916458.83it/s]

# %%
# Crearemos DataLoaders con un tamaño de lote de 102, lo que nos permitirá usar 10 lotes por ciclo
batch_size = 102
dataloaders = {'train': DataLoader(flowers_train, batch_size=batch_size)}

dataset_sizes = {'train': len(flowers_train)}
print(f'dataset_sizes = {dataset_sizes}')
# Out:
# dataset_sizes = {'train': 1020}

# %% [markdown]
# ## Visualización del conjunto de datos
#
# Aquí, veremos una cuadrícula de muestra del conjunto de datos. Vemos que hay varias imágenes de cada flor.

# %%
# Función de visualización extraída de: https://pytorch.org/tutorials/beginner/dcgan_faces_tutorial.html

# Trazar algunas imágenes de entrenamiento
real_batch = next(iter(dataloaders["train"]))
plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))

# %% [markdown]
# ## Creación de los modelos
#
# Las redes de generación y discriminación son mucho más complejas que las CNN estándar. Más abajo, hemos definido algunos parámetros que aparecen en el artículo en el que se presentaron las GAN y en el tutorial de PyTorch.

# %%
# Número de canales de las imágenes de entrenamiento. Para las imágenes en color, es 3
nc = 3

# Tamaño del vector latente z (es decir, tamaño del input del generador)
nz = 100

# Tamaño de los mapas de atributos del generador
ngf = 64

# Tamaño de los mapas de atributos del discriminador
ndf = 64

# %%
# TAREA: Añada las funciones de activación a los modelos
# Debería añadir una LeakyRelu que opere con una pendiente negativa de 0,2
# para cada función de activación del discriminador, EXCEPTO la última,
# que debería ser sigmoide
class Discriminator(nn.Module):
    def __init__(self, nc, ndf):
        super(Discriminator, self).__init__()
        self.pipeline = nn.Sequential(
            # El input es (nc) x 64 x 64

            nn.Conv2d(nc, ndf, 4, 2, 1, bias=False),
            # TAREA: Función de activación
            nn.LeakyReLU(0.2, inplace=True),
            # Definir tamaño. (ndf) x 32 x 32
            nn.Conv2d(ndf, ndf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 2),
            # TAREA: Función de activación
            nn.LeakyReLU(0.2, inplace=True),
            # Definir tamaño. (ndf*2) x 16 x 16
            nn.Conv2d(ndf * 2, ndf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 4),
            # TAREA: Función de activación
            nn.LeakyReLU(0.2, inplace=True),
            # Definir tamaño. (ndf*4) x 8 x 8
            nn.Conv2d(ndf * 4, ndf * 8, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 8),
            # TAREA: Función de activación
            nn.LeakyReLU(0.2, inplace=True),
            # Definir tamaño. (ndf*8) x 4 x 4
            nn.Conv2d(ndf * 8, 1, 4, 1, 0, bias=False),
            # TAREA: Función de activación
            nn.Sigmoid()
        )

    def forward(self, input):
        return self.pipeline(input)

# Para el generador, utilizar funciones ReLU estándar que operen
# para todas las funciones de activación, excepto la última,
# que debería ser una TanH
class Generator(nn.Module):
    def __init__(self, nc, nz, ngf):
        super(Generator, self).__init__()
        self.pipeline = nn.Sequential(
            # El input es Z, con una convolución
            nn.ConvTranspose2d( nz, ngf * 8, 4, 1, 0, bias=False),
            nn.BatchNorm2d(ngf * 8),
            # TAREA: Función de activación
            nn.ReLU(True),
            # Definir tamaño. (ngf*8) x 4 x 4
            nn.ConvTranspose2d(ngf * 8, ngf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 4),
            # TAREA: Función de activación
            nn.ReLU(True),
            # Definir tamaño. (ngf*4) x 8 x 8
            nn.ConvTranspose2d( ngf * 4, ngf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 2),
            # TAREA: Función de activación
            nn.ReLU(True),
            # Definir tamaño. (ngf*2) x 16 x 16
            nn.ConvTranspose2d( ngf * 2, ngf, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf),
            # TAREA: Función de activación
            nn.ReLU(True),
            # Definir tamaño. (ngf) x 32 x 32
            nn.ConvTranspose2d( ngf, nc, 4, 2, 1, bias=False),
            # TAREA: Función de activación
            nn.Tanh()
            # Definir tamaño. (nc) x 64 x 64
        )

    def forward(self, input):
        return self.pipeline(input)

# %%
# Inicialización de pesos personalizados, llama a netg y netD
# Esta función inicializa los pesos de ciertas capas en función de las distribuciones descritas en el artículo original
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# %%
# TAREA: Crear el discriminador y el generador
netD = Discriminator(nc, ndf).to(device)
netG = Generator(nc, nz, ngf).to(device)

# Aplicar la función weights_init para inicializar de forma aleatoria todos los pesos
#  to mean=0, stdev=0.2.
netD.apply(weights_init)
netG.apply(weights_init)

# Imprimir el modelo
print(netD)
print(netG)
# Out:
# Discriminator(
#   (pipeline): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (9): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2, inplace=True)
#     (11): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (12): Sigmoid()
#   )
# )
# Generator(
#   (pipeline): Sequential(
#     (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace=True)
#     (9): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ReLU(inplace=True)
#     (12): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (13): Tanh()
#   )
# )

# %% [markdown]
# ## Entrenamiento de los modelos
#
# Este bucle de entrenamiento es muy diferente de los que hemos utilizado en el pasado. Está especializado en el entrenamiento de GAN. Entrenaremos con todo el conjunto, sin dejar imágenes de validación ni de prueba, ya que nos interesa mostrarle al modelo tantas imágenes como sea posible para mejorar sus habilidades de creación de imágenes.

# %%
# Entrenamiento adaptado de: https://pytorch.org/tutorials/beginner/dcgan_faces_tutorial.html
# Establecer una convención sobre las eiquetas "real" y "falso" durante el entrenamiento
real_label = 1.
fake_label = 0.

# Crear un lote de vectores latentes que utilizaremos para visualizar
# la progresión del generador
fixed_noise = torch.randn(64, nz, 1, 1, device=device)

def train_GANS(netD, netG, dataloaders, dataset_sizes, criterion, optimizerD, optimizerG, num_epochs=25):
    since = time.time()

    # Hacer un seguimiento de la evolución de la pérdida y la precisión durante el entrenamiento
    training_curves = {}
    training_curves['G'] = []
    training_curves['D'] = []
    phase = 'train'

    for epoch in range(num_epochs):
        print(f'\nEpoch {epoch+1}/{num_epochs}')
        print('-' * 10)

        for _, inputs in enumerate(dataloaders[phase], 0):

            ############################
            # (1) Actualizar la red D: maximizar log(D(x)) + log(1 - D(G(z)))
            ###########################
            ## Entrenar con un lote solo de imágenes reales
            optimizerD.zero_grad()
            # Formatear el lote
            real_cpu = inputs[0].to(device)
            b_size = real_cpu.size(0)
            label = torch.full((b_size,), real_label, dtype=torch.float, device=device)
            # Hacer un forward pass del lote real a través de D
            output = netD(real_cpu).view(-1)
            # Calcular la pérdida con el lote real
            errD_real = criterion(output, label)
            # Calcular los gradientes de  D en la retropropagación
            errD_real.backward()
            D_x = output.mean().item()

            # Entrenar con un lote solo de imágenes falsas
            # Generar lote de vecores latentes
            noise = torch.randn(b_size, nz, 1, 1, device=device)
            # Generar lote de imágenes falsas con G
            fake = netG(noise)
            label.fill_(fake_label)
            # Clasificar el lote de imágenes falsas con D
            output = netD(fake.detach()).view(-1)
            # Calcular la pérdida de D con el lote falso
            errD_fake = criterion(output, label)
            # Calcular los gradientes de este lote, sumados a los anteriores
            errD_fake.backward()
            D_G_z1 = output.mean().item()
            # Computar el error de D como una suma con los lotes de imágenes falsas y reales
            errD = errD_real + errD_fake
            # Actualizar D
            optimizerD.step()

            ############################
            # (2) Actualizar la red G: maximizar log(D(G(z)))
            ###########################
            netG.zero_grad()
            label.fill_(real_label)  # Las etiquetas "falso" equivalen a "real" para el coste del generador
            # Como acabamos de actualizar D, realizamos otro forward pass del lote falso a través de D
            output = netD(fake).view(-1)
            # Calcular la pérdida de G a partir de este output
            errG = criterion(output, label)
            # Calcular los gradientes de G
            errG.backward()
            D_G_z2 = output.mean().item()
            # Actualizar G
            optimizerG.step()

            training_curves['D'].append(errD.item())
            training_curves['G'].append(errG.item())

            print(f'D Loss: {errD.item():.4f}  G Loss: {errG.item():.4f}')

    time_elapsed = time.time() - since
    print(f'\nTraining complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')

    return netD, netG, training_curves

# %%
# Número de ciclos de entrenamiento
num_epochs = 100

# Tasa de aprendizaje para los optimizadores
lr = 0.0002

# Hiperparámetro Beta1 para los optimizadores Adam
beta1 = 0.5

# TAREA: Inicializar la función BCELoss
criterion = nn.BCELoss()

# Definir optimizadores Adam para G y D
optimizerD = torch.optim.Adam(netD.parameters(), lr=lr, betas=(beta1, 0.999))
optimizerG = torch.optim.Adam(netG.parameters(), lr=lr, betas=(beta1, 0.999))

# Entrenar al modelo. También almacenaremos los resultados del entrenamiento para visualizarlo
netD, netG, training_curves = train_GANS(netD, netG, dataloaders, dataset_sizes,
                                     criterion, optimizerD, optimizerG, num_epochs=num_epochs)
# Out:
# Epoch 1/100
# ----------
# D Loss: 1.9301  G Loss: 4.3158
# D Loss: 1.5126  G Loss: 6.0846
# D Loss: 1.1675  G Loss: 5.7655
# D Loss: 1.0707  G Loss: 6.7407
# D Loss: 1.0362  G Loss: 6.2563
# D Loss: 1.0358  G Loss: 7.7950
# D Loss: 0.5776  G Loss: 7.4707
# D Loss: 0.6261  G Loss: 8.6281
# D Loss: 0.6920  G Loss: 7.7736
# D Loss: 1.0346  G Loss: 10.6244
#
# Epoch 2/100
# ----------
# D Loss: 0.5017  G Loss: 8.3123
# D Loss: 1.1236  G Loss: 11.6819
# D Loss: 0.8125  G Loss: 8.3188
# D Loss: 1.5940  G Loss: 13.8383
# D Loss: 0.5512  G Loss: 10.7347
# D Loss: 0.6159  G Loss: 8.3236
# D Loss: 1.5304  G Loss: 16.4255
# D Loss: 0.6927  G Loss: 14.3363
# D Loss: 0.5642  G Loss: 5.5683
# D Loss: 5.5169  G Loss: 15.1161
#
# Epoch 3/100
# ----------
# D Loss: 0.6675  G Loss: 14.5987
# D Loss: 0.8369  G Loss: 6.2172
# D Loss: 5.5918  G Loss: 14.4257
# D Loss: 0.6716  G Loss: 14.1398
# D Loss: 0.1936  G Loss: 8.5306
# D Loss: 1.8826  G Loss: 14.8376
# D Loss: 0.5146  G Loss: 12.6884
# D Loss: 0.2382  G Loss: 6.9865
# D Loss: 3.1690  G Loss: 17.1860
# D Loss: 0.9750  G Loss: 17.1811
#
# Epoch 4/100
# ----------
# D Loss: 0.2127  G Loss: 11.9445
# D Loss: 0.4984  G Loss: 8.5348
# D Loss: 1.7892  G Loss: 18.2094
# D Loss: 0.5347  G Loss: 18.1289
# D Loss: 0.2231  G Loss: 10.5689
# D Loss: 1.6220  G Loss: 16.7141
# D Loss: 0.4844  G Loss: 15.1322
# D Loss: 0.2153  G Loss: 7.4913
# D Loss: 3.1470  G Loss: 19.0006
# D Loss: 1.6551  G Loss: 19.1563
#
# Epoch 5/100
# ----------
# D Loss: 0.3429  G Loss: 14.7007
# D Loss: 0.1516  G Loss: 7.1581
# D Loss: 1.6088  G Loss: 16.7583
# D Loss: 0.3186  G Loss: 17.6062
# D Loss: 0.2648  G Loss: 13.0000
# D Loss: 0.1947  G Loss: 5.7575
# D Loss: 2.8106  G Loss: 18.5629
# D Loss: 0.8942  G Loss: 19.2309
# D Loss: 0.3220  G Loss: 13.1892
# D Loss: 0.2055  G Loss: 6.2967
#
# Epoch 6/100
# ----------
# D Loss: 3.1907  G Loss: 21.0333
# D Loss: 1.5350  G Loss: 21.8931
# D Loss: 0.6867  G Loss: 17.4183
# D Loss: 0.1503  G Loss: 11.2644
# D Loss: 0.0302  G Loss: 4.6295
# D Loss: 2.3684  G Loss: 18.2561
# D Loss: 0.2212  G Loss: 21.1238
# D Loss: 0.6434  G Loss: 17.2259
# D Loss: 0.3679  G Loss: 8.2702
# D Loss: 2.8825  G Loss: 19.2236
#
# Epoch 7/100
# ----------
# D Loss: 0.9740  G Loss: 17.6383
# D Loss: 0.6865  G Loss: 9.0262
# D Loss: 2.2434  G Loss: 16.0886
# D Loss: 1.3764  G Loss: 13.5040
# D Loss: 0.1367  G Loss: 7.0505
# D Loss: 0.8681  G Loss: 13.1779
# D Loss: 0.2452  G Loss: 12.4352
# D Loss: 0.3651  G Loss: 7.6944
# D Loss: 0.1999  G Loss: 5.2042
# D Loss: 0.8819  G Loss: 13.7778
#
# Epoch 8/100
# ----------
# D Loss: 0.4708  G Loss: 13.1117
# D Loss: 0.3037  G Loss: 8.7176
# D Loss: 0.6817  G Loss: 7.7751
# D Loss: 0.9715  G Loss: 12.4351
# D Loss: 0.4428  G Loss: 10.0659
# D Loss: 0.5945  G Loss: 8.9752
# D Loss: 0.3629  G Loss: 9.3023
# D Loss: 0.5363  G Loss: 6.2757
# D Loss: 0.8965  G Loss: 14.1764
# D Loss: 1.0112  G Loss: 11.3507
#
# Epoch 9/100
# ----------
# D Loss: 0.1173  G Loss: 6.5197
# D Loss: 0.7829  G Loss: 9.8184
# D Loss: 0.4568  G Loss: 8.1072
# D Loss: 0.3517  G Loss: 3.9765
# D Loss: 1.0221  G Loss: 11.2980
# D Loss: 0.9788  G Loss: 8.4511
# D Loss: 0.3306  G Loss: 3.2307
# D Loss: 1.1667  G Loss: 9.5187
# D Loss: 0.6538  G Loss: 7.6420
# D Loss: 0.2514  G Loss: 4.4601
#
# Epoch 10/100
# ----------
# D Loss: 0.9802  G Loss: 7.7703
# D Loss: 0.9260  G Loss: 4.7614
# D Loss: 0.3790  G Loss: 4.2134
# D Loss: 0.5697  G Loss: 5.3108
# D Loss: 0.2065  G Loss: 5.3338
# D Loss: 0.2732  G Loss: 4.3980
# D Loss: 0.3984  G Loss: 4.3246
# D Loss: 0.5510  G Loss: 3.0628
# D Loss: 0.4751  G Loss: 6.8746
# D Loss: 0.5879  G Loss: 4.0903
#
# Epoch 11/100
# ----------
# D Loss: 0.2375  G Loss: 4.1300
# D Loss: 0.3366  G Loss: 5.2965
# D Loss: 0.2205  G Loss: 4.8899
# D Loss: 0.2963  G Loss: 3.5191
# D Loss: 0.3327  G Loss: 5.4368
# D Loss: 0.3785  G Loss: 3.2817
# D Loss: 0.3400  G Loss: 4.3980
# D Loss: 0.3770  G Loss: 3.7663
# D Loss: 0.2664  G Loss: 4.5702
# D Loss: 0.3485  G Loss: 4.0750
#
# Epoch 12/100
# ----------
# D Loss: 0.2494  G Loss: 5.0166
# D Loss: 0.2972  G Loss: 4.0874
# D Loss: 0.3080  G Loss: 4.7911
# D Loss: 0.2964  G Loss: 3.8812
# D Loss: 0.4322  G Loss: 6.1967
# D Loss: 1.1565  G Loss: 0.6784
# D Loss: 2.5074  G Loss: 12.8303
# D Loss: 1.5639  G Loss: 10.8634
# D Loss: 0.5919  G Loss: 5.5091
# D Loss: 0.7602  G Loss: 5.0928
#
# Epoch 13/100
# ----------
# D Loss: 0.8030  G Loss: 9.5979
# D Loss: 0.9739  G Loss: 6.6271
# D Loss: 0.6972  G Loss: 1.7374
# D Loss: 1.8055  G Loss: 10.5810
# D Loss: 2.5559  G Loss: 5.8535
# D Loss: 0.7998  G Loss: 1.5244
# D Loss: 1.6925  G Loss: 6.9275
# D Loss: 1.1815  G Loss: 3.8173
# D Loss: 0.6836  G Loss: 3.5157
# D Loss: 1.1218  G Loss: 4.2402
#
# Epoch 14/100
# ----------
# D Loss: 0.7849  G Loss: 5.0694
# D Loss: 0.7615  G Loss: 3.4627
# D Loss: 1.0759  G Loss: 3.8288
# D Loss: 0.8101  G Loss: 3.5318
# D Loss: 1.2208  G Loss: 2.1082
# D Loss: 1.1903  G Loss: 6.0133
# D Loss: 0.7350  G Loss: 3.8427
# D Loss: 0.5595  G Loss: 3.2871
# D Loss: 0.5922  G Loss: 5.1446
# D Loss: 0.7565  G Loss: 2.7571
#
# Epoch 15/100
# ----------
# D Loss: 0.7225  G Loss: 5.7327
# D Loss: 0.7661  G Loss: 2.9692
# D Loss: 0.7742  G Loss: 5.4299
# D Loss: 0.5841  G Loss: 3.7264
# D Loss: 0.6557  G Loss: 2.3930
# D Loss: 1.0350  G Loss: 6.3166
# D Loss: 0.8860  G Loss: 2.5357
# D Loss: 0.6019  G Loss: 3.8665
# D Loss: 0.3961  G Loss: 4.9938
# D Loss: 0.5793  G Loss: 2.7202
#
# Epoch 16/100
# ----------
# D Loss: 0.4989  G Loss: 4.1225
# D Loss: 0.4760  G Loss: 3.9020
# D Loss: 0.6274  G Loss: 2.1706
# D Loss: 0.8737  G Loss: 6.0264
# D Loss: 1.0123  G Loss: 2.6513
# D Loss: 0.7296  G Loss: 3.7084
# D Loss: 0.3799  G Loss: 4.9448
# D Loss: 0.4872  G Loss: 3.6729
# D Loss: 0.4172  G Loss: 4.4735
# D Loss: 0.5018  G Loss: 4.0637
#
# Epoch 17/100
# ----------
# D Loss: 0.6447  G Loss: 3.1439
# D Loss: 0.7131  G Loss: 5.9140
# D Loss: 0.8221  G Loss: 3.4007
# D Loss: 0.5915  G Loss: 4.5214
# D Loss: 0.3583  G Loss: 5.6284
# D Loss: 0.5564  G Loss: 3.3535
# D Loss: 0.5905  G Loss: 4.7564
# D Loss: 0.3168  G Loss: 4.7578
# D Loss: 0.2589  G Loss: 4.2120
# D Loss: 0.4248  G Loss: 3.4993
#
# Epoch 18/100
# ----------
# D Loss: 0.8230  G Loss: 4.2645
# D Loss: 0.4013  G Loss: 5.1238
# D Loss: 0.3937  G Loss: 4.2920
# D Loss: 0.5378  G Loss: 5.0365
# D Loss: 0.1621  G Loss: 5.3718
# D Loss: 0.3193  G Loss: 4.1172
# D Loss: 0.5780  G Loss: 2.7746
# D Loss: 0.5504  G Loss: 6.9392
# D Loss: 0.3014  G Loss: 6.1908
# D Loss: 0.2029  G Loss: 3.8570
#
# Epoch 19/100
# ----------
# D Loss: 0.3687  G Loss: 3.0319
# D Loss: 0.6731  G Loss: 4.8384
# D Loss: 0.2172  G Loss: 5.4575
# D Loss: 0.3165  G Loss: 4.0452
# D Loss: 0.3396  G Loss: 4.3034
# D Loss: 0.3368  G Loss: 4.3709
# D Loss: 0.5775  G Loss: 3.4301
# D Loss: 0.3558  G Loss: 5.9252
# D Loss: 0.1361  G Loss: 5.9771
# D Loss: 0.2300  G Loss: 3.9377
#
# Epoch 20/100
# ----------
# D Loss: 0.5305  G Loss: 2.2862
# D Loss: 0.9202  G Loss: 10.0283
# D Loss: 1.0502  G Loss: 8.1368
# D Loss: 0.1287  G Loss: 5.2362
# D Loss: 0.0811  G Loss: 3.8137
# D Loss: 0.3183  G Loss: 5.5432
# D Loss: 0.1631  G Loss: 5.7036
# D Loss: 0.4204  G Loss: 3.5626
# D Loss: 0.5460  G Loss: 6.2614
# D Loss: 0.8490  G Loss: 4.1946
#
# Epoch 21/100
# ----------
# D Loss: 0.5584  G Loss: 5.0351
# D Loss: 0.5400  G Loss: 6.6063
# D Loss: 0.9055  G Loss: 4.0188
# D Loss: 0.5922  G Loss: 5.4377
# D Loss: 0.1122  G Loss: 6.2743
# D Loss: 0.2903  G Loss: 4.5834
# D Loss: 0.1762  G Loss: 4.4454
# D Loss: 0.7301  G Loss: 2.8028
# D Loss: 0.8297  G Loss: 8.3676
# D Loss: 0.5238  G Loss: 7.8495
#
# Epoch 22/100
# ----------
# D Loss: 0.1260  G Loss: 5.3885
# D Loss: 0.2100  G Loss: 4.2753
# D Loss: 1.0275  G Loss: 7.0555
# D Loss: 0.6128  G Loss: 5.5758
# D Loss: 0.1385  G Loss: 4.9910
# D Loss: 0.2890  G Loss: 4.9617
# D Loss: 0.2716  G Loss: 5.7340
# D Loss: 0.2932  G Loss: 4.6446
# D Loss: 0.3069  G Loss: 4.7652
# D Loss: 0.2678  G Loss: 5.6687
#
# Epoch 23/100
# ----------
# D Loss: 0.8201  G Loss: 2.2532
# D Loss: 1.3158  G Loss: 11.5007
# D Loss: 0.5092  G Loss: 11.0012
# D Loss: 0.5436  G Loss: 6.0153
# D Loss: 0.4021  G Loss: 3.6079
# D Loss: 0.6229  G Loss: 6.5445
# D Loss: 0.2549  G Loss: 6.1730
# D Loss: 0.1159  G Loss: 4.9161
# D Loss: 0.2478  G Loss: 4.6407
# D Loss: 0.2735  G Loss: 5.0068
#
# Epoch 24/100
# ----------
# D Loss: 1.3311  G Loss: 2.0847
# D Loss: 1.1858  G Loss: 8.3405
# D Loss: 0.2729  G Loss: 8.7453
# D Loss: 0.2933  G Loss: 7.0237
# D Loss: 0.1365  G Loss: 4.7613
# D Loss: 0.3266  G Loss: 4.6655
# D Loss: 0.2333  G Loss: 4.7722
# D Loss: 0.3975  G Loss: 4.0030
# D Loss: 0.4798  G Loss: 5.2619
# D Loss: 0.8657  G Loss: 2.5753
#
# Epoch 25/100
# ----------
# D Loss: 1.0482  G Loss: 5.6705
# D Loss: 0.3822  G Loss: 4.9550
# D Loss: 0.5952  G Loss: 2.4276
# D Loss: 0.4764  G Loss: 4.1130
# D Loss: 0.1988  G Loss: 5.3431
# D Loss: 0.2309  G Loss: 4.8643
# D Loss: 0.1693  G Loss: 4.2100
# D Loss: 0.6990  G Loss: 1.0888
# D Loss: 1.3335  G Loss: 7.4523
# D Loss: 0.9420  G Loss: 5.1895
#
# Epoch 26/100
# ----------
# D Loss: 0.1955  G Loss: 2.8362
# D Loss: 0.3464  G Loss: 4.1543
# D Loss: 0.6568  G Loss: 3.4729
# D Loss: 0.9524  G Loss: 4.5125
# D Loss: 0.2429  G Loss: 4.8185
# D Loss: 0.6437  G Loss: 2.0799
# D Loss: 1.0434  G Loss: 5.7899
# D Loss: 1.7518  G Loss: 0.9503
# D Loss: 1.6837  G Loss: 6.5216
# D Loss: 0.1852  G Loss: 7.1700
#
# Epoch 27/100
# ----------
# D Loss: 1.4037  G Loss: 2.0986
# D Loss: 0.9038  G Loss: 2.5263
# D Loss: 0.6594  G Loss: 4.8778
# D Loss: 0.8268  G Loss: 3.3888
# D Loss: 2.2121  G Loss: 0.7534
# D Loss: 2.1294  G Loss: 5.6092
# D Loss: 2.5148  G Loss: 1.9543
# D Loss: 0.8335  G Loss: 2.2154
# D Loss: 0.5361  G Loss: 3.1097
# D Loss: 0.5250  G Loss: 2.9476
#
# Epoch 28/100
# ----------
# D Loss: 0.5617  G Loss: 2.2953
# D Loss: 0.7483  G Loss: 2.5899
# D Loss: 0.6366  G Loss: 3.2676
# D Loss: 1.0787  G Loss: 0.7332
# D Loss: 1.9775  G Loss: 6.3622
# D Loss: 1.6269  G Loss: 3.2245
# D Loss: 0.5974  G Loss: 1.3166
# D Loss: 0.7934  G Loss: 3.9838
# D Loss: 1.0978  G Loss: 1.2245
# D Loss: 1.0428  G Loss: 3.8025
#
# Epoch 29/100
# ----------
# D Loss: 0.8673  G Loss: 2.0055
# D Loss: 0.8317  G Loss: 3.3756
# D Loss: 0.7133  G Loss: 2.4486
# D Loss: 0.7782  G Loss: 2.6708
# D Loss: 0.3357  G Loss: 4.1226
# D Loss: 0.4399  G Loss: 2.8959
# D Loss: 0.3588  G Loss: 3.2585
# D Loss: 0.5609  G Loss: 2.1909
# D Loss: 0.6242  G Loss: 3.4859
# D Loss: 0.4858  G Loss: 3.3161
#
# Epoch 30/100
# ----------
# D Loss: 0.4399  G Loss: 3.5919
# D Loss: 0.3168  G Loss: 4.2525
# D Loss: 0.5610  G Loss: 2.2187
# D Loss: 0.8433  G Loss: 5.8123
# D Loss: 0.2776  G Loss: 5.5979
# D Loss: 0.6862  G Loss: 1.5025
# D Loss: 1.2647  G Loss: 8.0899
# D Loss: 2.1505  G Loss: 2.9737
# D Loss: 0.6732  G Loss: 4.2118
# D Loss: 0.5381  G Loss: 6.0481
#
# Epoch 31/100
# ----------
# D Loss: 0.3419  G Loss: 5.0718
# D Loss: 0.3628  G Loss: 4.3406
# D Loss: 0.9666  G Loss: 3.1455
# D Loss: 0.7198  G Loss: 5.9152
# D Loss: 0.1707  G Loss: 5.8809
# D Loss: 0.4712  G Loss: 2.9763
# D Loss: 0.5465  G Loss: 5.7045
# D Loss: 0.6288  G Loss: 3.7830
# D Loss: 0.4767  G Loss: 4.4517
# D Loss: 0.4865  G Loss: 4.1515
#
# Epoch 32/100
# ----------
# D Loss: 0.5731  G Loss: 5.8514
# D Loss: 2.7946  G Loss: 0.5832
# D Loss: 2.5689  G Loss: 7.3983
# D Loss: 0.5680  G Loss: 7.0537
# D Loss: 0.4767  G Loss: 3.1913
# D Loss: 1.0108  G Loss: 4.3611
# D Loss: 0.5790  G Loss: 4.2452
# D Loss: 1.3167  G Loss: 1.3883
# D Loss: 1.5141  G Loss: 6.7259
# D Loss: 0.5677  G Loss: 5.7886
#
# Epoch 33/100
# ----------
# D Loss: 0.6987  G Loss: 1.7816
# D Loss: 1.2792  G Loss: 4.8796
# D Loss: 0.5487  G Loss: 4.5791
# D Loss: 0.9348  G Loss: 1.5776
# D Loss: 1.3446  G Loss: 4.3338
# D Loss: 0.7247  G Loss: 3.3999
# D Loss: 0.8775  G Loss: 1.3589
# D Loss: 1.0044  G Loss: 5.1921
# D Loss: 0.6759  G Loss: 3.4312
# D Loss: 0.3760  G Loss: 2.2342
#
# Epoch 34/100
# ----------
# D Loss: 0.7796  G Loss: 3.6085
# D Loss: 0.5465  G Loss: 3.1806
# D Loss: 0.8891  G Loss: 1.4316
# D Loss: 1.1780  G Loss: 3.7092
# D Loss: 0.4112  G Loss: 3.9359
# D Loss: 0.8439  G Loss: 1.1425
# D Loss: 1.2071  G Loss: 4.2924
# D Loss: 1.1528  G Loss: 1.8292
# D Loss: 0.6784  G Loss: 3.1938
# D Loss: 0.5323  G Loss: 3.3585
#
# Epoch 35/100
# ----------
# D Loss: 0.6865  G Loss: 2.3130
# D Loss: 0.8073  G Loss: 3.2997
# D Loss: 0.7719  G Loss: 2.2911
# D Loss: 0.8003  G Loss: 2.8166
# D Loss: 0.7689  G Loss: 3.2006
# D Loss: 0.8301  G Loss: 2.0210
# D Loss: 0.8730  G Loss: 1.6369
# D Loss: 0.9312  G Loss: 5.0942
# D Loss: 0.7687  G Loss: 2.6715
# D Loss: 0.4784  G Loss: 2.2563
#
# Epoch 36/100
# ----------
# D Loss: 0.6995  G Loss: 2.8698
# D Loss: 0.5163  G Loss: 2.8642
# D Loss: 0.4663  G Loss: 3.2790
# D Loss: 0.8083  G Loss: 1.4934
# D Loss: 0.9136  G Loss: 5.0893
# D Loss: 1.0843  G Loss: 1.6350
# D Loss: 0.8580  G Loss: 2.4719
# D Loss: 0.5773  G Loss: 3.9495
# D Loss: 0.7361  G Loss: 1.8488
# D Loss: 0.6727  G Loss: 3.2290
#
# Epoch 37/100
# ----------
# D Loss: 0.8602  G Loss: 1.7379
# D Loss: 0.8278  G Loss: 3.0122
# D Loss: 0.5271  G Loss: 3.1780
# D Loss: 0.4370  G Loss: 2.9384
# D Loss: 0.6176  G Loss: 1.5827
# D Loss: 0.8958  G Loss: 5.4408
# D Loss: 1.0720  G Loss: 2.2006
# D Loss: 0.4928  G Loss: 2.4200
# D Loss: 0.4774  G Loss: 4.3668
# D Loss: 0.9444  G Loss: 1.7078
#
# Epoch 38/100
# ----------
# D Loss: 0.5933  G Loss: 3.1664
# D Loss: 0.6370  G Loss: 2.5296
# D Loss: 0.7259  G Loss: 2.8763
# D Loss: 0.7733  G Loss: 2.2856
# D Loss: 0.5511  G Loss: 3.3776
# D Loss: 0.8986  G Loss: 1.1913
# D Loss: 0.9259  G Loss: 5.0866
# D Loss: 0.8085  G Loss: 2.8202
# D Loss: 0.2728  G Loss: 2.4190
# D Loss: 0.3997  G Loss: 3.7860
#
# Epoch 39/100
# ----------
# D Loss: 0.4984  G Loss: 3.0591
# D Loss: 0.7830  G Loss: 1.9106
# D Loss: 0.7117  G Loss: 4.3278
# D Loss: 0.5819  G Loss: 2.8745
# D Loss: 0.5594  G Loss: 1.8896
# D Loss: 0.9589  G Loss: 4.7113
# D Loss: 0.9154  G Loss: 2.0017
# D Loss: 0.4480  G Loss: 3.1177
# D Loss: 0.4574  G Loss: 3.4736
# D Loss: 0.6160  G Loss: 2.7923
#
# Epoch 40/100
# ----------
# D Loss: 0.4614  G Loss: 3.2672
# D Loss: 0.5979  G Loss: 3.0874
# D Loss: 0.4882  G Loss: 3.6916
# D Loss: 0.4645  G Loss: 2.7379
# D Loss: 0.6661  G Loss: 5.2989
# D Loss: 1.0813  G Loss: 1.5329
# D Loss: 1.2277  G Loss: 5.9599
# D Loss: 1.1122  G Loss: 2.9037
# D Loss: 0.6052  G Loss: 4.4047
# D Loss: 0.3810  G Loss: 4.1765
#
# Epoch 41/100
# ----------
# D Loss: 0.6758  G Loss: 2.4160
# D Loss: 0.9012  G Loss: 4.0662
# D Loss: 0.5415  G Loss: 3.8084
# D Loss: 0.3895  G Loss: 2.7574
# D Loss: 0.5247  G Loss: 4.6718
# D Loss: 0.5320  G Loss: 2.4898
# D Loss: 0.6146  G Loss: 4.2611
# D Loss: 0.5163  G Loss: 2.8336
# D Loss: 0.5765  G Loss: 3.4499
# D Loss: 0.6752  G Loss: 3.0364
#
# Epoch 42/100
# ----------
# D Loss: 0.5401  G Loss: 3.1690
# D Loss: 0.6321  G Loss: 2.8890
# D Loss: 0.6390  G Loss: 3.9113
# D Loss: 0.5849  G Loss: 3.0064
# D Loss: 0.6016  G Loss: 3.1598
# D Loss: 0.6016  G Loss: 3.4654
# D Loss: 0.3728  G Loss: 3.4146
# D Loss: 0.3502  G Loss: 3.9757
# D Loss: 0.3974  G Loss: 3.0990
# D Loss: 0.3664  G Loss: 3.2706
#
# Epoch 43/100
# ----------
# D Loss: 0.6219  G Loss: 3.2762
# D Loss: 0.6540  G Loss: 2.2142
# D Loss: 0.5614  G Loss: 4.2254
# D Loss: 0.4306  G Loss: 3.1584
# D Loss: 0.2953  G Loss: 2.8060
# D Loss: 0.4042  G Loss: 3.4618
# D Loss: 0.3596  G Loss: 3.1736
# D Loss: 0.4377  G Loss: 2.8353
# D Loss: 0.4067  G Loss: 3.4573
# D Loss: 0.5452  G Loss: 1.9695
#
# Epoch 44/100
# ----------
# D Loss: 0.5558  G Loss: 4.4184
# D Loss: 0.6275  G Loss: 2.2032
# D Loss: 0.4870  G Loss: 3.5180
# D Loss: 0.3353  G Loss: 3.7203
# D Loss: 0.2968  G Loss: 3.5358
# D Loss: 0.6164  G Loss: 1.9803
# D Loss: 0.7446  G Loss: 5.6222
# D Loss: 0.6876  G Loss: 3.3129
# D Loss: 0.3716  G Loss: 2.7874
# D Loss: 0.6060  G Loss: 5.0759
#
# Epoch 45/100
# ----------
# D Loss: 0.2871  G Loss: 4.3258
# D Loss: 0.4671  G Loss: 2.6408
# D Loss: 0.8874  G Loss: 5.1033
# D Loss: 0.7668  G Loss: 1.8143
# D Loss: 1.0876  G Loss: 6.3636
# D Loss: 0.9150  G Loss: 2.5563
# D Loss: 0.5933  G Loss: 3.7150
# D Loss: 0.4898  G Loss: 4.7988
# D Loss: 0.6094  G Loss: 3.0100
# D Loss: 0.6444  G Loss: 3.6834
#
# Epoch 46/100
# ----------
# D Loss: 0.6762  G Loss: 3.4395
# D Loss: 0.6565  G Loss: 4.7169
# D Loss: 0.5684  G Loss: 2.7246
# D Loss: 0.5694  G Loss: 6.2950
# D Loss: 0.2651  G Loss: 4.4707
# D Loss: 0.4025  G Loss: 2.9736
# D Loss: 0.6676  G Loss: 6.8591
# D Loss: 0.8861  G Loss: 1.1489
# D Loss: 1.7498  G Loss: 8.2333
# D Loss: 1.8962  G Loss: 1.6840
#
# Epoch 47/100
# ----------
# D Loss: 1.1035  G Loss: 5.5924
# D Loss: 1.0209  G Loss: 2.9542
# D Loss: 0.4201  G Loss: 3.3325
# D Loss: 0.4850  G Loss: 4.3021
# D Loss: 0.4667  G Loss: 3.2931
# D Loss: 0.5544  G Loss: 3.1566
# D Loss: 0.6099  G Loss: 3.3358
# D Loss: 0.4485  G Loss: 3.1110
# D Loss: 0.5268  G Loss: 2.7800
# D Loss: 0.5054  G Loss: 4.0588
#
# Epoch 48/100
# ----------
# D Loss: 0.5357  G Loss: 2.6327
# D Loss: 0.4055  G Loss: 3.5726
# D Loss: 0.5179  G Loss: 3.3470
# D Loss: 0.3700  G Loss: 3.0269
# D Loss: 0.4055  G Loss: 3.8024
# D Loss: 0.5162  G Loss: 2.8318
# D Loss: 0.4168  G Loss: 3.2868
# D Loss: 0.3296  G Loss: 3.3126
# D Loss: 0.3371  G Loss: 3.6828
# D Loss: 0.3528  G Loss: 3.8266
#
# Epoch 49/100
# ----------
# D Loss: 0.2639  G Loss: 3.6866
# D Loss: 0.3133  G Loss: 3.5664
# D Loss: 0.3791  G Loss: 3.6524
# D Loss: 0.3382  G Loss: 4.1791
# D Loss: 0.3970  G Loss: 2.9491
# D Loss: 0.3806  G Loss: 3.7140
# D Loss: 0.3188  G Loss: 3.8065
# D Loss: 0.2308  G Loss: 3.8576
# D Loss: 0.4079  G Loss: 3.8425
# D Loss: 0.3951  G Loss: 3.4151
#
# Epoch 50/100
# ----------
# D Loss: 0.4894  G Loss: 4.2921
# D Loss: 0.4999  G Loss: 2.5817
# D Loss: 0.7376  G Loss: 5.5359
# D Loss: 0.6307  G Loss: 2.8598
# D Loss: 0.4594  G Loss: 4.6823
# D Loss: 0.4372  G Loss: 3.2007
# D Loss: 0.5183  G Loss: 5.4137
# D Loss: 0.4752  G Loss: 3.0799
# D Loss: 0.4804  G Loss: 4.2871
# D Loss: 0.3296  G Loss: 4.2393
#
# Epoch 51/100
# ----------
# D Loss: 0.3146  G Loss: 4.0977
# D Loss: 0.3563  G Loss: 4.1640
# D Loss: 0.4584  G Loss: 3.6364
# D Loss: 0.3127  G Loss: 4.4261
# D Loss: 0.3218  G Loss: 3.9257
# D Loss: 0.3879  G Loss: 3.6586
# D Loss: 0.4057  G Loss: 6.0617
# D Loss: 0.2677  G Loss: 4.8871
# D Loss: 0.2931  G Loss: 3.0402
# D Loss: 0.5968  G Loss: 7.3824
#
# Epoch 52/100
# ----------
# D Loss: 0.3182  G Loss: 5.5716
# D Loss: 0.6087  G Loss: 4.0262
# D Loss: 0.8199  G Loss: 8.1021
# D Loss: 0.5965  G Loss: 3.3573
# D Loss: 1.3602  G Loss: 10.7101
# D Loss: 2.1239  G Loss: 3.4139
# D Loss: 1.1972  G Loss: 5.7069
# D Loss: 0.4967  G Loss: 5.2371
# D Loss: 1.0003  G Loss: 3.4160
# D Loss: 1.1441  G Loss: 6.8549
#
# Epoch 53/100
# ----------
# D Loss: 0.9575  G Loss: 1.4343
# D Loss: 1.1830  G Loss: 8.5315
# D Loss: 1.6605  G Loss: 3.0318
# D Loss: 0.8860  G Loss: 4.6812
# D Loss: 0.4657  G Loss: 4.1936
# D Loss: 0.3376  G Loss: 2.8492
# D Loss: 0.5868  G Loss: 4.0089
# D Loss: 0.5284  G Loss: 3.1401
# D Loss: 0.4397  G Loss: 2.4212
# D Loss: 0.5052  G Loss: 3.2147
#
# Epoch 54/100
# ----------
# D Loss: 0.3699  G Loss: 3.8113
# D Loss: 0.4435  G Loss: 2.6302
# D Loss: 0.3816  G Loss: 3.3913
# D Loss: 0.3707  G Loss: 3.2634
# D Loss: 0.2840  G Loss: 3.6355
# D Loss: 0.4269  G Loss: 2.6248
# D Loss: 0.4579  G Loss: 2.9569
# D Loss: 0.4081  G Loss: 3.7203
# D Loss: 0.4263  G Loss: 2.8635
# D Loss: 0.6394  G Loss: 3.5128
#
# Epoch 55/100
# ----------
# D Loss: 0.5358  G Loss: 2.4931
# D Loss: 0.7002  G Loss: 4.7362
# D Loss: 0.7888  G Loss: 1.9713
# D Loss: 0.7805  G Loss: 5.1109
# D Loss: 0.2446  G Loss: 4.4710
# D Loss: 0.3182  G Loss: 2.4127
# D Loss: 0.7976  G Loss: 5.7388
# D Loss: 0.6566  G Loss: 3.0978
# D Loss: 0.4609  G Loss: 3.7036
# D Loss: 0.4429  G Loss: 3.9530
#
# Epoch 56/100
# ----------
# D Loss: 0.5092  G Loss: 3.5533
# D Loss: 0.7081  G Loss: 3.0091
# D Loss: 0.8165  G Loss: 5.6617
# D Loss: 0.8174  G Loss: 2.0615
# D Loss: 0.8857  G Loss: 6.6455
# D Loss: 0.7030  G Loss: 2.8002
# D Loss: 0.8059  G Loss: 5.1104
# D Loss: 0.7483  G Loss: 2.8274
# D Loss: 0.7443  G Loss: 6.0438
# D Loss: 0.9834  G Loss: 2.5027
#
# Epoch 57/100
# ----------
# D Loss: 0.4528  G Loss: 3.9483
# D Loss: 0.4370  G Loss: 4.5698
# D Loss: 0.2759  G Loss: 4.1328
# D Loss: 0.5430  G Loss: 3.6453
# D Loss: 1.2058  G Loss: 0.7509
# D Loss: 1.8108  G Loss: 7.2938
# D Loss: 1.1515  G Loss: 4.2217
# D Loss: 0.1649  G Loss: 2.9732
# D Loss: 0.6913  G Loss: 5.4255
# D Loss: 0.6325  G Loss: 2.6287
#
# Epoch 58/100
# ----------
# D Loss: 0.6912  G Loss: 5.2680
# D Loss: 1.0688  G Loss: 1.4809
# D Loss: 1.1109  G Loss: 7.0161
# D Loss: 1.0170  G Loss: 3.5628
# D Loss: 0.3622  G Loss: 3.4028
# D Loss: 0.5365  G Loss: 4.5829
# D Loss: 0.2375  G Loss: 4.1558
# D Loss: 0.3183  G Loss: 3.2704
# D Loss: 0.6471  G Loss: 3.4670
# D Loss: 0.5497  G Loss: 2.9041
#
# Epoch 59/100
# ----------
# D Loss: 0.5354  G Loss: 4.4814
# D Loss: 0.6564  G Loss: 2.6029
# D Loss: 0.8237  G Loss: 5.5860
# D Loss: 0.7491  G Loss: 2.7378
# D Loss: 0.5079  G Loss: 4.7318
# D Loss: 0.4237  G Loss: 3.7655
# D Loss: 0.5578  G Loss: 4.2314
# D Loss: 0.3674  G Loss: 3.8341
# D Loss: 0.4796  G Loss: 5.0961
# D Loss: 0.4886  G Loss: 3.4165
#
# Epoch 60/100
# ----------
# D Loss: 0.4652  G Loss: 4.7636
# D Loss: 0.5622  G Loss: 3.3574
# D Loss: 0.6485  G Loss: 6.6235
# D Loss: 0.4060  G Loss: 4.7852
# D Loss: 0.4521  G Loss: 2.7201
# D Loss: 1.0014  G Loss: 7.2039
# D Loss: 1.3609  G Loss: 2.1005
# D Loss: 1.5433  G Loss: 8.3674
# D Loss: 1.2047  G Loss: 4.5051
# D Loss: 0.3922  G Loss: 2.8414
#
# Epoch 61/100
# ----------
# D Loss: 0.7592  G Loss: 7.0673
# D Loss: 1.2042  G Loss: 1.9689
# D Loss: 0.9253  G Loss: 5.2158
# D Loss: 0.7334  G Loss: 2.8338
# D Loss: 0.6567  G Loss: 3.1435
# D Loss: 0.7432  G Loss: 2.6283
# D Loss: 0.7845  G Loss: 4.8778
# D Loss: 0.7965  G Loss: 2.2409
# D Loss: 0.6766  G Loss: 4.6022
# D Loss: 0.4345  G Loss: 3.5856
#
# Epoch 62/100
# ----------
# D Loss: 0.5176  G Loss: 2.8298
# D Loss: 0.8118  G Loss: 3.0589
# D Loss: 0.7251  G Loss: 3.5785
# D Loss: 0.4593  G Loss: 3.5362
# D Loss: 0.5946  G Loss: 1.8822
# D Loss: 0.6315  G Loss: 4.9821
# D Loss: 0.3073  G Loss: 4.2509
# D Loss: 0.2031  G Loss: 3.2313
# D Loss: 0.3436  G Loss: 3.8247
# D Loss: 0.4365  G Loss: 2.9141
#
# Epoch 63/100
# ----------
# D Loss: 0.3995  G Loss: 4.3470
# D Loss: 0.4259  G Loss: 3.1795
# D Loss: 0.3855  G Loss: 3.1058
# D Loss: 0.5958  G Loss: 4.2147
# D Loss: 0.4684  G Loss: 2.7819
# D Loss: 0.6674  G Loss: 4.0222
# D Loss: 0.3501  G Loss: 3.9084
# D Loss: 0.3172  G Loss: 3.2817
# D Loss: 0.4933  G Loss: 4.6937
# D Loss: 0.5768  G Loss: 2.4228
#
# Epoch 64/100
# ----------
# D Loss: 0.6977  G Loss: 5.7733
# D Loss: 0.7497  G Loss: 3.0793
# D Loss: 0.5918  G Loss: 4.2857
# D Loss: 0.4345  G Loss: 3.7605
# D Loss: 0.5627  G Loss: 3.2879
# D Loss: 0.6299  G Loss: 2.8587
# D Loss: 0.7017  G Loss: 5.8089
# D Loss: 0.8040  G Loss: 2.1914
# D Loss: 0.9732  G Loss: 5.9255
# D Loss: 0.8053  G Loss: 2.9708
#
# Epoch 65/100
# ----------
# D Loss: 0.5776  G Loss: 4.8081
# D Loss: 0.4343  G Loss: 3.5313
# D Loss: 0.4781  G Loss: 4.0967
# D Loss: 0.3652  G Loss: 4.1762
# D Loss: 0.3478  G Loss: 3.5237
# D Loss: 0.4489  G Loss: 4.3922
# D Loss: 0.3690  G Loss: 3.1174
# D Loss: 0.3225  G Loss: 4.2587
# D Loss: 0.4539  G Loss: 3.2205
# D Loss: 0.4133  G Loss: 4.6325
#
# Epoch 66/100
# ----------
# D Loss: 0.6344  G Loss: 1.8829
# D Loss: 1.0129  G Loss: 6.7818
# D Loss: 0.9804  G Loss: 2.8912
# D Loss: 0.4394  G Loss: 3.4889
# D Loss: 0.4859  G Loss: 4.4110
# D Loss: 0.5546  G Loss: 2.6900
# D Loss: 0.5500  G Loss: 5.3042
# D Loss: 0.4749  G Loss: 3.0608
# D Loss: 0.6202  G Loss: 4.1770
# D Loss: 0.4472  G Loss: 2.8923
#
# Epoch 67/100
# ----------
# D Loss: 0.4785  G Loss: 4.1628
# D Loss: 0.7161  G Loss: 1.9021
# D Loss: 0.8189  G Loss: 5.6450
# D Loss: 0.9598  G Loss: 2.2084
# D Loss: 0.6533  G Loss: 4.8436
# D Loss: 0.5724  G Loss: 2.8126
# D Loss: 0.4023  G Loss: 4.1868
# D Loss: 0.5744  G Loss: 2.8808
# D Loss: 0.4935  G Loss: 3.6655
# D Loss: 0.5339  G Loss: 2.8396
#
# Epoch 68/100
# ----------
# D Loss: 0.5602  G Loss: 4.3180
# D Loss: 0.6008  G Loss: 2.4737
# D Loss: 0.5824  G Loss: 4.1468
# D Loss: 0.4035  G Loss: 3.5139
# D Loss: 0.4167  G Loss: 2.7204
# D Loss: 0.5086  G Loss: 4.2921
# D Loss: 0.4801  G Loss: 3.1477
# D Loss: 0.3381  G Loss: 3.8306
# D Loss: 0.5393  G Loss: 2.3418
# D Loss: 0.5546  G Loss: 5.1463
#
# Epoch 69/100
# ----------
# D Loss: 0.3621  G Loss: 3.9713
# D Loss: 0.5477  G Loss: 2.4114
# D Loss: 0.6085  G Loss: 6.0089
# D Loss: 0.7263  G Loss: 2.6784
# D Loss: 0.7412  G Loss: 4.2697
# D Loss: 0.5906  G Loss: 3.0881
# D Loss: 0.4230  G Loss: 4.0378
# D Loss: 0.4298  G Loss: 3.2739
# D Loss: 0.4513  G Loss: 2.4975
# D Loss: 0.4951  G Loss: 4.5074
#
# Epoch 70/100
# ----------
# D Loss: 0.3231  G Loss: 3.6961
# D Loss: 0.5723  G Loss: 2.2127
# D Loss: 0.5506  G Loss: 3.3710
# D Loss: 0.3904  G Loss: 3.5255
# D Loss: 0.2631  G Loss: 3.3603
# D Loss: 0.3948  G Loss: 2.9274
# D Loss: 0.4253  G Loss: 3.4634
# D Loss: 0.5553  G Loss: 1.8290
# D Loss: 0.5437  G Loss: 5.7907
# D Loss: 0.7747  G Loss: 1.8815
#
# Epoch 71/100
# ----------
# D Loss: 0.4151  G Loss: 4.0704
# D Loss: 0.3146  G Loss: 3.8123
# D Loss: 0.3814  G Loss: 3.7961
# D Loss: 0.3124  G Loss: 3.5624
# D Loss: 0.5168  G Loss: 2.3312
# D Loss: 0.6384  G Loss: 5.5944
# D Loss: 0.8887  G Loss: 1.2097
# D Loss: 1.0522  G Loss: 6.3626
# D Loss: 0.8723  G Loss: 3.0738
# D Loss: 0.3482  G Loss: 3.3291
#
# Epoch 72/100
# ----------
# D Loss: 0.2663  G Loss: 4.5877
# D Loss: 0.4702  G Loss: 2.5406
# D Loss: 0.4980  G Loss: 4.5661
# D Loss: 0.2774  G Loss: 4.5761
# D Loss: 0.5087  G Loss: 1.9448
# D Loss: 0.6337  G Loss: 5.5923
# D Loss: 0.4445  G Loss: 3.4191
# D Loss: 0.4527  G Loss: 2.1787
# D Loss: 0.6034  G Loss: 4.7045
# D Loss: 0.6027  G Loss: 2.5702
#
# Epoch 73/100
# ----------
# D Loss: 0.6256  G Loss: 5.0204
# D Loss: 0.5602  G Loss: 3.1862
# D Loss: 0.4834  G Loss: 3.4862
# D Loss: 0.3994  G Loss: 3.5244
# D Loss: 0.4274  G Loss: 3.9866
# D Loss: 0.7952  G Loss: 1.1717
# D Loss: 1.3835  G Loss: 7.2583
# D Loss: 1.5669  G Loss: 2.5330
# D Loss: 0.6469  G Loss: 4.4123
# D Loss: 0.5005  G Loss: 4.2859
#
# Epoch 74/100
# ----------
# D Loss: 0.4251  G Loss: 2.4162
# D Loss: 0.6889  G Loss: 4.9502
# D Loss: 0.8464  G Loss: 1.2947
# D Loss: 1.6445  G Loss: 6.7118
# D Loss: 2.2260  G Loss: 0.5231
# D Loss: 1.9060  G Loss: 5.5387
# D Loss: 0.4661  G Loss: 4.5928
# D Loss: 0.8105  G Loss: 1.4907
# D Loss: 1.0477  G Loss: 3.8794
# D Loss: 0.3780  G Loss: 4.0466
#
# Epoch 75/100
# ----------
# D Loss: 0.7288  G Loss: 1.4299
# D Loss: 0.6819  G Loss: 3.9216
# D Loss: 0.6808  G Loss: 2.0011
# D Loss: 0.6478  G Loss: 5.2191
# D Loss: 0.4924  G Loss: 3.0965
# D Loss: 0.4489  G Loss: 2.0754
# D Loss: 0.4271  G Loss: 4.1832
# D Loss: 0.2299  G Loss: 4.0562
# D Loss: 0.5044  G Loss: 1.6631
# D Loss: 0.7239  G Loss: 4.7185
#
# Epoch 76/100
# ----------
# D Loss: 0.4290  G Loss: 3.6349
# D Loss: 0.6578  G Loss: 1.5670
# D Loss: 0.9440  G Loss: 6.1130
# D Loss: 1.0121  G Loss: 2.7337
# D Loss: 0.4935  G Loss: 2.3460
# D Loss: 0.6108  G Loss: 4.0950
# D Loss: 0.3779  G Loss: 3.5827
# D Loss: 0.2653  G Loss: 3.1216
# D Loss: 0.5761  G Loss: 2.3343
# D Loss: 0.5218  G Loss: 4.2187
#
# Epoch 77/100
# ----------
# D Loss: 0.3544  G Loss: 3.5746
# D Loss: 0.7658  G Loss: 1.3858
# D Loss: 0.7530  G Loss: 4.8634
# D Loss: 0.2844  G Loss: 4.5864
# D Loss: 0.4158  G Loss: 1.8731
# D Loss: 1.0377  G Loss: 5.8041
# D Loss: 0.9789  G Loss: 2.5460
# D Loss: 0.4162  G Loss: 2.7208
# D Loss: 0.3939  G Loss: 3.6798
# D Loss: 0.4943  G Loss: 2.8503
#
# Epoch 78/100
# ----------
# D Loss: 0.4024  G Loss: 3.5399
# D Loss: 0.5758  G Loss: 2.0260
# D Loss: 0.5682  G Loss: 3.6508
# D Loss: 0.4930  G Loss: 2.9455
# D Loss: 0.3163  G Loss: 3.5417
# D Loss: 0.5759  G Loss: 1.9637
# D Loss: 0.6144  G Loss: 5.2706
# D Loss: 0.4730  G Loss: 3.3411
# D Loss: 0.4081  G Loss: 2.0853
# D Loss: 0.6120  G Loss: 4.6649
#
# Epoch 79/100
# ----------
# D Loss: 0.4085  G Loss: 3.6427
# D Loss: 0.6864  G Loss: 1.3485
# D Loss: 0.8611  G Loss: 4.7176
# D Loss: 0.4170  G Loss: 3.7809
# D Loss: 0.4095  G Loss: 2.2067
# D Loss: 0.4313  G Loss: 3.7311
# D Loss: 0.3157  G Loss: 3.9346
# D Loss: 0.4287  G Loss: 2.4899
# D Loss: 0.4818  G Loss: 3.0670
# D Loss: 0.6488  G Loss: 3.9147
#
# Epoch 80/100
# ----------
# D Loss: 0.6369  G Loss: 1.5333
# D Loss: 0.8878  G Loss: 5.5709
# D Loss: 1.2204  G Loss: 1.5222
# D Loss: 1.1121  G Loss: 6.0855
# D Loss: 0.4781  G Loss: 4.6066
# D Loss: 0.3341  G Loss: 2.0409
# D Loss: 0.6971  G Loss: 4.9229
# D Loss: 0.4136  G Loss: 3.6483
# D Loss: 0.4439  G Loss: 1.6586
# D Loss: 0.6921  G Loss: 4.5952
#
# Epoch 81/100
# ----------
# D Loss: 0.5427  G Loss: 2.4048
# D Loss: 0.7600  G Loss: 2.9285
# D Loss: 0.5556  G Loss: 3.6349
# D Loss: 0.3770  G Loss: 2.9799
# D Loss: 0.4769  G Loss: 3.0906
# D Loss: 0.5515  G Loss: 3.4891
# D Loss: 0.4216  G Loss: 3.0535
# D Loss: 0.4609  G Loss: 4.4724
# D Loss: 0.5654  G Loss: 2.0906
# D Loss: 0.6475  G Loss: 5.1352
#
# Epoch 82/100
# ----------
# D Loss: 0.5974  G Loss: 2.8781
# D Loss: 0.5492  G Loss: 2.8920
# D Loss: 0.4941  G Loss: 4.4163
# D Loss: 0.4699  G Loss: 2.6274
# D Loss: 0.3656  G Loss: 3.9766
# D Loss: 0.4086  G Loss: 2.7049
# D Loss: 0.6790  G Loss: 4.9843
# D Loss: 0.7343  G Loss: 2.0074
# D Loss: 0.7689  G Loss: 4.2497
# D Loss: 0.6051  G Loss: 2.4876
#
# Epoch 83/100
# ----------
# D Loss: 0.4024  G Loss: 4.3697
# D Loss: 0.7918  G Loss: 1.9124
# D Loss: 0.9092  G Loss: 4.8659
# D Loss: 0.4438  G Loss: 3.3994
# D Loss: 0.3884  G Loss: 3.6004
# D Loss: 0.4844  G Loss: 2.9720
# D Loss: 0.5341  G Loss: 3.4383
# D Loss: 0.3694  G Loss: 4.0744
# D Loss: 0.6657  G Loss: 1.4437
# D Loss: 1.0214  G Loss: 5.9939
#
# Epoch 84/100
# ----------
# D Loss: 0.3782  G Loss: 4.6575
# D Loss: 0.5624  G Loss: 1.8504
# D Loss: 1.8096  G Loss: 7.4846
# D Loss: 1.8681  G Loss: 1.6876
# D Loss: 1.0246  G Loss: 5.2762
# D Loss: 0.9389  G Loss: 2.3255
# D Loss: 0.7065  G Loss: 3.9865
# D Loss: 0.4431  G Loss: 4.3937
# D Loss: 0.9050  G Loss: 1.9891
# D Loss: 0.8409  G Loss: 4.1189
#
# Epoch 85/100
# ----------
# D Loss: 0.5931  G Loss: 2.9096
# D Loss: 0.6748  G Loss: 2.8484
# D Loss: 0.7256  G Loss: 3.4751
# D Loss: 0.4446  G Loss: 3.7179
# D Loss: 0.4997  G Loss: 2.3301
# D Loss: 0.5409  G Loss: 3.3662
# D Loss: 0.3620  G Loss: 3.4859
# D Loss: 0.4616  G Loss: 2.6453
# D Loss: 0.5261  G Loss: 3.4171
# D Loss: 0.7609  G Loss: 2.1376
#
# Epoch 86/100
# ----------
# D Loss: 0.4371  G Loss: 3.4706
# D Loss: 0.4686  G Loss: 3.2091
# D Loss: 0.6699  G Loss: 1.7841
# D Loss: 0.8399  G Loss: 6.1715
# D Loss: 0.8990  G Loss: 2.9534
# D Loss: 0.3884  G Loss: 2.7188
# D Loss: 0.5871  G Loss: 5.1094
# D Loss: 0.5263  G Loss: 3.5392
# D Loss: 0.4746  G Loss: 2.3405
# D Loss: 0.5392  G Loss: 4.4147
#
# Epoch 87/100
# ----------
# D Loss: 0.4913  G Loss: 2.9377
# D Loss: 0.5852  G Loss: 2.3145
# D Loss: 0.7269  G Loss: 4.7799
# D Loss: 0.4741  G Loss: 3.3942
# D Loss: 0.4759  G Loss: 2.1363
# D Loss: 0.7343  G Loss: 4.6641
# D Loss: 0.6016  G Loss: 2.6880
# D Loss: 0.4122  G Loss: 3.8061
# D Loss: 0.5744  G Loss: 2.6113
# D Loss: 0.6513  G Loss: 4.2060
#
# Epoch 88/100
# ----------
# D Loss: 0.3999  G Loss: 3.7495
# D Loss: 0.5568  G Loss: 2.3197
# D Loss: 0.7050  G Loss: 3.2582
# D Loss: 0.3572  G Loss: 4.0692
# D Loss: 0.3184  G Loss: 3.6517
# D Loss: 0.5388  G Loss: 1.9573
# D Loss: 0.8089  G Loss: 5.5290
# D Loss: 0.7809  G Loss: 2.4884
# D Loss: 0.6840  G Loss: 4.0407
# D Loss: 0.5304  G Loss: 3.0892
#
# Epoch 89/100
# ----------
# D Loss: 0.5831  G Loss: 3.0645
# D Loss: 0.7308  G Loss: 2.7975
# D Loss: 0.6309  G Loss: 4.0607
# D Loss: 0.3346  G Loss: 3.4786
# D Loss: 0.5617  G Loss: 2.5110
# D Loss: 0.6192  G Loss: 4.6720
# D Loss: 0.3228  G Loss: 3.8099
# D Loss: 0.3283  G Loss: 3.7209
# D Loss: 0.6422  G Loss: 1.9065
# D Loss: 0.8315  G Loss: 5.6014
#
# Epoch 90/100
# ----------
# D Loss: 0.2624  G Loss: 5.3799
# D Loss: 0.3318  G Loss: 2.9147
# D Loss: 0.6057  G Loss: 3.7107
# D Loss: 0.3800  G Loss: 3.6875
# D Loss: 0.4378  G Loss: 3.2931
# D Loss: 0.6937  G Loss: 2.1773
# D Loss: 0.8068  G Loss: 4.8792
# D Loss: 0.7155  G Loss: 2.5595
# D Loss: 0.6386  G Loss: 3.4077
# D Loss: 0.5016  G Loss: 3.3464
#
# Epoch 91/100
# ----------
# D Loss: 0.4085  G Loss: 2.7717
# D Loss: 0.5582  G Loss: 4.0563
# D Loss: 0.8263  G Loss: 1.6158
# D Loss: 0.8198  G Loss: 5.2800
# D Loss: 0.5850  G Loss: 3.0862
# D Loss: 0.3745  G Loss: 3.3850
# D Loss: 0.4284  G Loss: 3.3816
# D Loss: 0.4125  G Loss: 4.1608
# D Loss: 0.7465  G Loss: 1.8478
# D Loss: 0.7553  G Loss: 5.0686
#
# Epoch 92/100
# ----------
# D Loss: 0.8179  G Loss: 2.2076
# D Loss: 0.6073  G Loss: 4.3101
# D Loss: 0.3378  G Loss: 3.8912
# D Loss: 0.4422  G Loss: 3.7200
# D Loss: 0.5093  G Loss: 2.9188
# D Loss: 0.8742  G Loss: 4.7745
# D Loss: 0.8333  G Loss: 1.9266
# D Loss: 1.1084  G Loss: 6.7674
# D Loss: 1.3923  G Loss: 2.3505
# D Loss: 0.6865  G Loss: 3.9694
#
# Epoch 93/100
# ----------
# D Loss: 0.3667  G Loss: 4.5961
# D Loss: 0.6223  G Loss: 2.2171
# D Loss: 0.6156  G Loss: 3.7092
# D Loss: 0.5122  G Loss: 3.4100
# D Loss: 0.4043  G Loss: 4.2604
# D Loss: 1.0327  G Loss: 0.7231
# D Loss: 1.9495  G Loss: 6.7655
# D Loss: 1.8340  G Loss: 2.7386
# D Loss: 0.4557  G Loss: 2.9784
# D Loss: 0.4971  G Loss: 4.3534
#
# Epoch 94/100
# ----------
# D Loss: 0.3980  G Loss: 3.2819
# D Loss: 0.6642  G Loss: 2.3594
# D Loss: 0.5542  G Loss: 3.8468
# D Loss: 0.4147  G Loss: 3.4569
# D Loss: 0.7473  G Loss: 1.8473
# D Loss: 0.8989  G Loss: 5.0138
# D Loss: 0.5836  G Loss: 3.0076
# D Loss: 0.3354  G Loss: 3.4091
# D Loss: 0.5200  G Loss: 3.2220
# D Loss: 0.5252  G Loss: 2.9220
#
# Epoch 95/100
# ----------
# D Loss: 0.4745  G Loss: 3.5461
# D Loss: 0.5935  G Loss: 2.4973
# D Loss: 0.5775  G Loss: 2.7715
# D Loss: 0.5442  G Loss: 4.1010
# D Loss: 0.3707  G Loss: 3.5012
# D Loss: 0.5298  G Loss: 2.3235
# D Loss: 0.5008  G Loss: 4.2620
# D Loss: 0.3408  G Loss: 3.6034
# D Loss: 0.4627  G Loss: 2.3653
# D Loss: 0.5899  G Loss: 4.0993
#
# Epoch 96/100
# ----------
# D Loss: 0.4648  G Loss: 3.0462
# D Loss: 0.4311  G Loss: 3.4022
# D Loss: 0.5351  G Loss: 2.5532
# D Loss: 0.6384  G Loss: 4.5900
# D Loss: 0.6570  G Loss: 2.3224
# D Loss: 0.6571  G Loss: 4.0143
# D Loss: 0.5117  G Loss: 3.1356
# D Loss: 0.4250  G Loss: 3.2826
# D Loss: 0.5872  G Loss: 3.1450
# D Loss: 0.5867  G Loss: 2.2184
#
# Epoch 97/100
# ----------
# D Loss: 0.7331  G Loss: 5.5750
# D Loss: 0.8314  G Loss: 2.7426
# D Loss: 0.6023  G Loss: 3.3564
# D Loss: 0.4904  G Loss: 4.3482
# D Loss: 0.4006  G Loss: 3.7796
# D Loss: 0.7304  G Loss: 1.5516
# D Loss: 1.1294  G Loss: 6.3706
# D Loss: 0.6977  G Loss: 4.0099
# D Loss: 0.5888  G Loss: 1.6489
# D Loss: 0.7740  G Loss: 5.0620
#
# Epoch 98/100
# ----------
# D Loss: 0.4255  G Loss: 3.6617
# D Loss: 0.4863  G Loss: 2.8332
# D Loss: 0.7041  G Loss: 3.8749
# D Loss: 0.6165  G Loss: 3.0265
# D Loss: 0.6845  G Loss: 3.7309
# D Loss: 0.6395  G Loss: 2.9797
# D Loss: 0.5951  G Loss: 3.4548
# D Loss: 0.3355  G Loss: 4.2558
# D Loss: 0.4289  G Loss: 2.8977
# D Loss: 0.4886  G Loss: 3.9078
#
# Epoch 99/100
# ----------
# D Loss: 0.5798  G Loss: 3.1636
# D Loss: 0.5065  G Loss: 3.3321
# D Loss: 0.7653  G Loss: 3.1882
# D Loss: 0.5494  G Loss: 3.7028
# D Loss: 0.4812  G Loss: 2.5318
# D Loss: 0.6062  G Loss: 4.7126
# D Loss: 0.5782  G Loss: 2.6047
# D Loss: 0.6175  G Loss: 4.9920
# D Loss: 0.4777  G Loss: 3.2957
# D Loss: 0.5753  G Loss: 2.9579
#
# Epoch 100/100
# ----------
# D Loss: 0.5552  G Loss: 4.3900
# D Loss: 0.7617  G Loss: 1.7772
# D Loss: 0.9376  G Loss: 5.0954
# D Loss: 0.4886  G Loss: 3.4378
# D Loss: 0.3656  G Loss: 3.2254
# D Loss: 0.5524  G Loss: 3.3801
# D Loss: 0.4649  G Loss: 4.0306
# D Loss: 0.3737  G Loss: 3.6965
# D Loss: 0.4532  G Loss: 2.7561
# D Loss: 0.6247  G Loss: 3.8990
#
# Training complete in 9m 1s

# %% [markdown]
# ## Visualizar los resultados
#
# Aquí podemos ver las curvas de entrenamiento de las dos redes y algunos ejemplos de las imágenes que ha creado el modelo generativo.

# %%
plt.figure(figsize=(10,5))
plt.title("Generator and Discriminator Loss During Training")
plt.plot(training_curves['G'] ,label="G")
plt.plot(training_curves['D'] ,label="D")
plt.xlabel("iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# Tomar un lote de imágenes reales del dataloader
real_batch = next(iter(dataloaders['train']))

# Trazar las imágenes reales
plt.figure(figsize=(15,15))
plt.subplot(1,2,1)
plt.axis("off")
plt.title("Real Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=5, normalize=True).cpu(),(1,2,0)))

# Generar imágenes falsas
img_list = []
with torch.no_grad():
    fake = netG(fixed_noise).detach().cpu()
    img_list.append(vutils.make_grid(fake, padding=2, normalize=True))

# Trazar las imágenes falsas del último ciclo
plt.subplot(1,2,2)
plt.axis("off")
plt.title("Fake Images")
plt.imshow(np.transpose(img_list[-1],(1,2,0)))
plt.show()

# %% [markdown]
# Después de entrenar durante 100 ciclos, el modelo es capaz de generar imágenes de flores falsas que parecen más o menos convincentes. Pruebe a entrenarlo con otro conjunto de datos si quiere generar otro tipo de imágenes.
